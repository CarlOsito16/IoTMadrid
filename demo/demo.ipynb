# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import plotly.express as px
import plotly.graph_objects as go

from functions import clean_air_data
import pingouin as pg

# %%
from functions import *

# %%
AIR_FILE_PATH = "/Users/carlosito/Library/CloudStorage/OneDrive-Personal/AIT material/DANIclass/2-Iot/Project/Madrid/air/2020calidad-aire-diario.csv"
METEOR_FILE_PATH = "/Users/carlosito/Library/CloudStorage/OneDrive-Personal/AIT material/DANIclass/2-Iot/Project/Madrid/meteo/2019meteorologicos-diarios.csv"
TRAFFIC_FILE_PATH = "/Users/carlosito/Library/CloudStorage/OneDrive-Personal/AIT material/DANIclass/2-Iot/Project/Madrid/traffic/monthlyTraffic/03-2020-traffic.csv"

# %%
traffic_df =  clean_monthly_traffic(TRAFFIC_FILE_PATH)
traffic_df.head()
# Out:
# Dropping 11146945
# [3]
# [2020]
# [24 50 47]
#        fecha    id  true_intensity  linked_air_station  MES   ANO  \
# 0 2020-03-01  1001      323.398438                  24    3  2020
# 1 2020-03-01  1002      320.500000                  24    3  2020
# 2 2020-03-01  1006      282.812500                  24    3  2020
# 3 2020-03-01  3421      155.273438                  50    3  2020
# 4 2020-03-01  3449       46.171233                  50    3  2020
#
#     air_station_name  air_station_type
# 0      Casa de Campo          Suburban
# 1      Casa de Campo          Suburban
# 2      Casa de Campo          Suburban
# 3  Plaza de Castilla  Roadside Traffic
# 4  Plaza de Castilla  Roadside Traffic

# %%
sns.lineplot(data= traffic_df, x= 'fecha', y = 'true_intensity', hue = 'air_station_type')
plt.xticks(rotation = 45)
plt.plot()
# Out:
# []

# %%
    
g = sns.FacetGrid(traffic_df, col="meteor_factor", hue = 'station_type', sharey=False)
g.map(sns.lineplot,  "datestamp",'value')
[plt.setp(ax.get_xticklabels(), rotation=45) for ax in g.axes.flat]
plt.legend()

# %%
meteor_df =  clean_meteor_data(METEOR_FILE_PATH)
meteor_df.head()
# Out:
# Cleaning METEOR data...
# Dropping: 116 rows
#    ESTACION   ANO MES  MAGNITUD variable  value sensor_valid meteor_factor  \
# 0       102  2019  01        81      D01   0.66            V    Wind Speed
# 1       102  2019  02        81      D01   4.32            V    Wind Speed
# 2       102  2019  03        81      D01   1.57            V    Wind Speed
# 3       102  2019  04        81      D01   1.32            V    Wind Speed
# 4       102  2019  05        81      D01   2.06            V    Wind Speed
#
#        station_name  datestamp      station_type
# 0  J.M.D. Moratalaz 2019-01-01  Urban Background
# 1  J.M.D. Moratalaz 2019-02-01  Urban Background
# 2  J.M.D. Moratalaz 2019-03-01  Urban Background
# 3  J.M.D. Moratalaz 2019-04-01  Urban Background
# 4  J.M.D. Moratalaz 2019-05-01  Urban Background

# %%
meteor_df.shape
# Out:
# (4348, 10)

# %%
air_df =  clean_air_data(AIR_FILE_PATH)
air_df.head()
# Out:
# Cleaning AIR data...
# Dropping: 0 rows
#    ESTACION   ANO MES  MAGNITUD variable  value meteor_station station_type  \
# 0        24  2020  01         7      D01   52.0  Casa de Campo     Suburban
# 1        24  2020  02         7      D01    1.0  Casa de Campo     Suburban
# 2        24  2020  03         7      D01    1.0  Casa de Campo     Suburban
# 3        24  2020  04         7      D01    1.0  Casa de Campo     Suburban
# 4        24  2020  05         7      D01    1.0  Casa de Campo     Suburban
#
#     latitude  longitude  datestamp pollutant_name
# 0  40.419358  -3.747345 2020-01-01             NO
# 1  40.419358  -3.747345 2020-02-01             NO
# 2  40.419358  -3.747345 2020-03-01             NO
# 3  40.419358  -3.747345 2020-04-01             NO
# 4  40.419358  -3.747345 2020-05-01             NO
